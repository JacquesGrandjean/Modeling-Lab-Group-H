# %% [markdown]
# ## Classical Thermodynamics:
#
# # 1. Three Basic Assumptions of the Langmuir Model
#
# 1. The surface containing adsorption sites is perfectly flat with no corrugations.
#    Additionally, all sites on the surface are energetically equivalent.
# 2. Each site can hold only one molecule.
# 3. There are no interactions between adsorbed molecules.

# %% [markdown]
# # 2. Prove.
#
# 1. At high pressure, the gas uptake reaches a plateau.
#
# We start from the Langmuir equation:
#
# $$
# q(P) = q_{\max}\,\frac{K(T)P}{1+K(T)P}
# $$
#
# where
# - $q(P)$ = adsorbed amount at pressure $P$,
# - $q_{\max} > 0$ = maximum adsorption capacity (monolayer coverage),
# - $K(T) > 0$ = affinity constant.
#
#
# Step 1: Rewrite fraction
# Divide numerator and denominator by $P$:
#
# $$
# q(P) = q_{\max}\,\frac{K(T)}{\tfrac{1}{P}+K(T)}.
# $$
#
#
# Step 2: Limit at high pressure
# As $P \to \infty$, we have $\tfrac{1}{P} \to 0$, so:
#
# $$
# \lim_{P \to \infty} q(P) = q_{\max}\,\frac{K(T)}{0+K(T)} = q_{\max}.
# $$
#
#
# Step 3: Monotonicity
# Differentiate with respect to $P$:
#
# $$
# \frac{dq}{dP} = q_{\max}\,\frac{K(T)}{(1+K(T)P)^2} > 0 \quad \forall P \ge 0.
# $$
#
# Thus $q(P)$ is strictly increasing, but approaches a finite upper bound.
#
#     - At low pressure, the gas uptake is a linear function of pressure
#
# We consider the Langmuir equation:
#
# $$
# q(P) = q_{\max}\,\frac{K(T)P}{1+K(T)P}
# $$
#
#
# Step 1: Behavior at low pressure
# When $P \to 0$, the denominator can be expanded:
#
# $$
# 1 + K(T)P \approx 1 \quad \text{(since $K(T)P \ll 1$)}.
# $$
#
# Thus:
#
# $$
# q(P) \approx q_{\max}\,(K(T)P).
# $$
#
#
# Step 2: Linear dependence
# This shows that:
#
# $$
# q(P) \sim (q_{\max} K(T))\,P \quad \text{as } P \to 0.
# $$
#
#
# Conclusion
# At low pressure, the adsorbed amount $q(P)$ is **directly proportional to pressure**.
# The proportionality constant is the **Henry constant**:
#
# $$
# K_H = q_{\max} K(T).
# $$
#
# # 3. Deduce the temperature dependance of the Henry's coefficient
#
# Temperature dependence of the Henry coefficient
#
# From the low-pressure limit of the Langmuir isotherm we have the Henry constant:
#
# $$
# K_H \;=\; q_{\max}\,K(T),
# $$
#
# where
#
# - $q_{\max}$ = monolayer capacity
# - $K(T)$ = Langmuir affinity (equilibrium) constant
#
# Thermodynamic temperature dependence of $b$
#
# Since $K(T)$ is an equilibrium constant, it follows the usual thermodynamic relation:
#
# $$
# K(T)=\exp\!\left(-\tfrac{\Delta G_{\mathrm{ads}}}{RT}\right)
# =\exp\!\left(\tfrac{\Delta S_{\mathrm{ads}}}{R}\right)\,\exp\!\left(-\tfrac{\Delta H_{\mathrm{ads}}}{RT}\right),
# $$
#
# where
#
# - $\Delta G_{\mathrm{ads}}$ = Gibbs free energy of adsorption
# - $\Delta H_{\mathrm{ads}}$ = enthalpy change of adsorption
# - $\Delta S_{\mathrm{ads}}$ = entropy change of adsorption
# - $R$ = gas constant
# - $T$ = absolute temperature
#
# Expression for $K_H(T)$
#
# Therefore:
#
# $$
# K_H(T)=q_{\max}(T)\,\exp\!\left(\tfrac{\Delta S_{\mathrm{ads}}}{R}\right)\,
# \exp\!\left(-\tfrac{\Delta H_{\mathrm{ads}}}{RT}\right).
# $$
# Taking logarithms gives a van ’t Hoff–like form:
#
# $$
# \ln K_H(T)=\ln q_{\max}(T)+\frac{\Delta S_{\mathrm{ads}}}{R}
# -\frac{\Delta H_{\mathrm{ads}}}{RT}.
# $$
#
# Common simplification
#
# If $q_{\max}$ is approximately temperature-independent:
#
# $$
# K_H(T)=K_0\,\exp\!\left(-\tfrac{\Delta H_{\mathrm{ads}}}{RT}\right),
# \qquad
# \ln K_H(T)=\ln K_0-\frac{\Delta H_{\mathrm{ads}}}{RT},
# $$
#
# with
#
# $$
# K_0 = q_{\max}^0 \exp\!\left(\tfrac{\Delta S_{\mathrm{ads}}}{R}\right).
# $$
#
# Physical interpretation
#
# - If adsorption is **exothermic** ($\Delta H_{\mathrm{ads}}<0$):
#   $K_H$ **decreases** as $T$ increases → adsorption favored at low $T$.
#
# - If adsorption is **endothermic** ($\Delta H_{\mathrm{ads}}>0$):
#   $K_H$ **increases** with $T$.
#
#
# **Conclusion:** The Henry coefficient $K_H$ has an **Arrhenius/van ’t Hoff–type dependence** on temperature, governed primarily by $\Delta H_{\mathrm{ads}}$ and $\Delta S_{\mathrm{ads}}$.

# %% [markdown]
# # 4 Determining Langmuir Parameters for CO2 Absorption
# Step 1: Fitting Isotherms to the Lanmguir Model
#
# The Langmuir absoprtion model is given by:
#
#
# $$
# q(P) = q_{\max}\,\frac{K(T)P}{1+K(T)P}
# $$
#
#
# At 263K, fit the isotherm to the Langmuir equation to detemrine $q_{\text{sat}}$.Indeed, at the lowest temperature (263 K), absorption is strongest which means that the isotherm will reach closest to saturation and we can extract a good estimate of $q_{\text{sat}}$. Then, at all temperatures (263, 303, 343 K), fit the curves again using the same $q_{\text{sat}}$ value but allowing K(T) to vary. This give three temperature-dependant Langmuir constants: K(263), K(303) and K(343). This can be done, since $q_{\text{sat}}$ is independant of temperature, since the MOF structure doesn't change with temperature.
# Graphically:
#  - Plot the experimental absorption isotherms q against P.
#  - Fit them with the Langmuir model curves.
#  - Extract K(T) for each temperature.
#
# Step 2: Extracting Thermodynamic Parameters with Van't Hoff Equation
#
# From Step 1, we obtained the Langmuir equilibrium constants K(T) at three temperatures.
#
# $$
# K(T) = k_0 \, \exp\left(-\frac{\Delta H}{R T}\right)
# $$
#
# where:
# - $K(T)$: the equilibrium constant at temperature $T$
# - $K_0$: the pre-exponential factor, $K_0 = q_{\max}^0 \exp\left(\frac{\Delta S_\mathrm{ads}}{R}\right)$
# - $\Delta H_\mathrm{ads}$: the adsorption enthalpy
# - $R$: the universal gas constant
# - $T$: the absolute temperature in Kelvin
#
#
# Taking the natural logarithm gives the van ’t Hoff equation:
#
# $$
# \ln K(T) = \ln k_0 - \frac{\Delta H}{R} \cdot \frac{1}{T}
# $$
#
# <div align="center">
#   <img src="image.png" alt="image" width="900">
# </div>
#
# Using the graph:
# - On the X-axis: $1/T$ in $K^{-1}$
# - On the Y-axis: $\ln K(T)$
# - Red points: the three calculated $K(T)$ values
# - Blue line: linear regression through the points
#
# From the graph:
#
# 1. Slope:
#    $$\text{slope} = -\frac{\Delta H}{R}
#
# 2. Calculate $\Delta H$:
#
#    Using $R = 8.314 \text{ J} \cdot \text{mol}^{-1} \cdot \text{K}^{-1}$
#
#    $$\Delta H = -\text{slope} \times R$$
#
# 3. Intercept:
#    $$\text{intercept} = \ln K_0$$
#
# 4. Calculate $K_0$:
#
#    Exponentiating gives the pre-exponential factor $K_0$:
#
#    $$K_0 = e^{\text{intercept}}$$

# %% [markdown]
# # 5 Langmuir Adsorption Analysis and Henry’s Coefficient Calculation
#
# <div align="center">
#
# | Temperature (K) | Equilibrium Constant K(T) |
# |:---------------:|:-------------------------:|
# | 263            | $6.75 \times 10^{-6} \text{ Pa}^{-1}$ |
# | 303            | $1.48 \times 10^{-6} \text{ Pa}^{-1}$ |
# | 343            | $5.16 \times 10^{-7} \text{ Pa}^{-1}$ |
#
# </div>
#
# With this data, the following lineare regression can be generated:
#
# <div align="center">
#   <img src="image.png" alt="image" width="900">
# </div>
#
# Using the information explained in part 4, the following equations can be used:
#
# $$\Delta H = -\text{slope} \times R$$
#
# and
#
# $$K_0 = e^{\text{intercept}}$$
#
# Kowing $R = 8.314 \text{ J} \cdot \text{mol}^{-1} \cdot \text{K}^{-1}$ and the $intercept = -22.9712 the following values can be determined:
#
# - **ΔH** ≈ -24.2 kJ/mol
# - **k₀** ≈ 1.05 × 10⁻¹⁰ Pa⁻¹

# %% [markdown]
# ## Statistical Thermodynamics
#
# In this part, the statistical thermodymamic properties of adsorption are treated. THe canonical ensemble will be used for the calculation of the heat of adsorption at zero loading.
#
# # 1. In the context of adsorption, describe the Canonical Ensemble in a few words
#
# In the context of adsorption, the canonical ensemble is caracterised by a fixed temperature T, adsorption sites, and number of adsorbed molecules N.
# The system exchanges energy with a heat bath, and the probabilities are described with the canonical partition function Q.
#
# # 2. Write the partition function (Q) for the Canonical Ensemble
#
# The partition function can be written as below:
#
# $$
# Q_{N,V,T} \;=\; \frac{1}{\Lambda^{3N} N!}\;
# \int \exp\!\left[-\frac{U(\mathbf r)}{k_B T}\right]\; \mathrm d\mathbf r^{3N}
# $$
#
# # 3. Write the probability P<sub>v</sub> of finding the system in a microstate v with energy E<sub>v</sub>.
#
# The probability P<sub>v</sub> of finding the system in microstate \(v\) with energy E<sub>v</sub> (canonical ensemble) is
# $$
# P_v \;=\; \frac{e^{-\beta E_v}}{Q},
# \qquad
# Q \;=\; \sum_{w} e^{-\beta E_w},
# \qquad
# \beta \;=\; \frac{1}{k_{\mathrm B} T}.
# $$
#
# # 4. Prove the identities below:
#
# Proof 1:
#
# The Helmoltz Free Energy and the statistical definition of entropy can be written:
#
# $$
# F(N,V,T) = -\,k_{\mathrm B}T\,\ln Q(N,V,T),
# \qquad
# S = -\left(\frac{\partial F}{\partial T}\right)_{N,V}.
# $$
#
# At fixed number of particles and volumes, the free energy can be differentiated with respect to T:
#
# $$
# \frac{\partial F}{\partial T}
# = -k_{\mathrm B}\ln Q
#   -k_{\mathrm B}T\,\frac{1}{Q}\,\frac{\partial Q}{\partial T}
# = -k_{\mathrm B}\ln Q
#   -k_{\mathrm B}T\left(\frac{\partial \ln Q}{\partial T}\right)_{N,V}.
# $$
#
# Adding a minus sign and uising the definition of entropy gives us:
#
# $$
# \boxed{
# \langle S\rangle
# = -\left(\frac{\partial F}{\partial T}\right)_{N,V}
# = k_{\mathrm B}\ln Q
#  + k_{\mathrm B}T\left(\frac{\partial \ln Q}{\partial T}\right)_{N,V}
# }
# $$
#
# Proof 2:
#
# The Helmoltz Free Energy and the statistical definition of pressure can be written:
#
# $$
# F(N,V,T) = -\,k_{\mathrm B}T\,\ln Q(N,V,T),
# \qquad
# P = -\left(\frac{\partial F}{\partial V}\right)_{N,T}.
# $$
#
# Using the same reasoning as above, the free energy can be differentiated in respect to V:
#
# $$
# \frac{\partial F}{\partial V}
# = -k_{\mathrm B}T\,\frac{1}{Q}\,\frac{\partial Q}{\partial V}
# = -k_{\mathrm B}T\left(\frac{\partial \ln Q}{\partial V}\right)_{N,T}.
# $$
#
# Adding a minus sign and using the definition of pressure gives us:
#
# $$
# \boxed{
# P \;=\; k_{\mathrm B}T
# \left(\frac{\partial \ln Q}{\partial V}\right)_{N,T}
# }
# $$
#
#
# $$
# \mu \;=\; -\,k_{\mathrm B}T
# \left(\frac{\partial \ln Q}{\partial N}\right)_{V,T}
# $$
#
# $$
# E \;=\; k_{\mathrm B}T^{2}
# \left(\frac{\partial \ln Q}{\partial T}\right)_{V,N}
# $$
